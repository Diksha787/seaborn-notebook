# %% [markdown]
# Seaborn library used for data visualization.Data Visualization is the art of representing data in the form of graphs. It is a useful tool for professionals who work with data, i.e., financial analysts, business analysts, data analysts, data scientists, to name a few examples.

# %% [markdown]
# ## Start the EDA

# %%
import numpy as np ## working with array
import seaborn as sns # for data visualization
import pandas as pd # for data analysis
import matplotlib.pyplot as plt # for data visualization
from scipy.stats import norm # for scientific Computing

# %% [markdown]
# ## Lineplot

# %% [markdown]
# A single line plot presents data on x-y axis using a line joining datapoints. To obtain a graph Seaborn comes with an inbuilt function to draw a line plot called lineplot().

# %% [markdown]
# Syntax: lineplot(x,y,data)
#
# where,
#
# x– data variable for x-axis
#
# y- data variable for y-axis
#
# data- data to be plotted

# %%
url = 'https://raw.githubusercontent.com/sanketchavan5595/EDA-on-bestselling-books-on-Amazon-/main/bestsellers%20with%20categories.csv'
bestsellers_df = pd.read_csv(url)
bestsellers_df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
bestsellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
bestsellers_df.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
bestsellers_df.shape #(There are total of 550 books listed as bestsellers on amazon)
# Out:
# (550, 7)

# %% [markdown]
# Categorical variables
# - Genre
# - Year

# %% [markdown]
# Numerical variables:
#   - Reviews
#   - User Rating
#   - Price

# %%
# hue=used for categorical data that  will produce line different color

plt.figure(figsize=(7,7))

sns.lineplot(x = 'Price', y = 'Reviews', hue = 'Genre',data = bestsellers_df);

plt.title("Price v/s Reviews")
# Out:
# Text(0.5, 1.0, 'Price v/s Reviews')

# %% [markdown]
# Fiction book have more reviews than the non-fiction book but non-fiction books have higher prices

# %%
plt.figure(figsize = (16,9))
sns.set(style='darkgrid',)

# Draw line plot of size and total_bill with parameters and hue "day"
sns.lineplot(x = "Year", y = "User Rating", data = bestsellers_df, hue = "Genre",
            style = "Genre", palette = "hot", dashes = False,size=0.10,
            markers = ["o", "*"],  legend="brief",)  ## o-circle,*,p,P=star,pentagon,Plus

plt.title("Line Plot", fontsize = 20)
plt.xlabel("Size", fontsize = 15)
plt.ylabel("Total Bill", fontsize = 15)
plt.show()

# %% [markdown]
# Attributes:
#
#     Context: plotting context parameters
#     Style: defines style
#     Palette: sets a color palette
#     Font
#     Font_scale: sets font size
#     Color_codes: If set True then palette is activated, short hand notations for colors can be remapped  from the palette.

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# scatterplot() function is used to plot the data and depict the relationship between the values using the scatter visualization.

# %%
# load the dataset 
df = sns.load_dataset('titanic')

# %% [markdown]
# The titanic data frames describe the survival status of individual passengers on the Titanic. The titanic data frame does not contain information from the crew, but it does contain actual ages of half of the passengers.

# %% [markdown]
# ## Insite of data

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
#     survival -> person who have survived the crash and this is a categorical data where 0 means Not survived and 1 means survived.
#     Pclass -> This represent the passenger class and it is also a categorical data where 1 = Upper,2 = Middle,3 = Lower.
#     sex --> gender
#     Age --> age of the passenger
#     sibsp -> It determine the family relationship Sibling = brother, sister, stepbrother, stepsister Spouse = husband, wife (mistresses and fiancés were ignored)
#     parch -> (Parental relationship)The dataset defines family relations in this way... Parent = mother, father,Child = daughter, son, stepdaughter, stepson,Some children travelled only with a nanny, therefore parch=0 for them.
#     ticket -> ticket number
#     fare -> charge/cost of the ticket
#     cabin -> cabin number (boggy number/room number for example)
#     embarked -> port from where the passenger board the ship C = Cherbourg, Q = Queenstown, S = Southampton.
#     alive -> Passenger is alive or not
#     alone -> weather passenger is travelling alone or with some one.

# %% [markdown]
# ## Histogram

# %% [markdown]
#  A histogram is basically used to represent data provided in a form of some groups.It is accurate method for the graphical representation of numerical data distribution.It is a type of bar plot where X-axis represents the bin ranges while Y-axis gives information about frequency.

# %% [markdown]
# seaborn.histplot(data=None, , x=None, y=None, hue=None, weights=None, stat='count', bins='auto', binwidth=None, binrange=None, discrete=None, cumulative=False, common_bins=True, common_norm=True, multiple='layer', element='bars', fill=True, shrink=1, kde=False, kde_kws=None, line_kws=None, thresh=0, pthresh=None, pmax=None, cbar=False, cbar_ax=None, cbar_kws=None, palette=None, hue_order=None, hue_norm=None, color=None, log_scale=None, legend=True, ax=None, *kwargs)

# %%
sns.histplot(data=df,x='survived', color='c',legend=True)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='Count'>

# %% [markdown]
# From the above we can see that in survived column there are only two different categories i.e. 0 mean passenger have not survived and 1 means passenger has survived.The value range is for survived is app(300) and for not survived is app(more than 500).

# %%
sns.histplot(data=df,x='pclass')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='Count'>

# %% [markdown]
# From this my observation is that passenger class is a categorical data and have 3 differnt class where nearly 200 family buy the first class tickets and then followed by 2nd class i.e more that 150 but less than 200 and then followed by 3rd class max of people buy this tickets

# %%
sns.histplot(df['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Count'>

# %% [markdown]
# From this obervation we can see that male people compare to ffemale travel the most.

# %%
sns.histplot(df['embark_town'])
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='Count'>

# %% [markdown]
# From the above observation we can see that most of the people board at southampton port then followed by cherbourg and then very few at queenstown.

# %%
sns.histplot(df['age'], kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# form the observation we can see that age group between (15 yrs to 40 yrs ) are more travelling on ship

# %% [markdown]
#   ## dist plot
#   Seaborn distplot lets you show a histogram with a line on it. This can be shown in all kinds of variations. We use seaborn in combination with matplotlib, the Python plotting module. A distplot plots a univariate distribution of observations.

# %% [markdown]
# seaborn.distplot(a=None, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None, x=None)

# %%
sns.distplot(x=df['fare'])
# Out:
# C:\Python3.10.4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x = df['survived'])
# Out:
# C:\Python3.10.4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Bar plot:

# %% [markdown]
# A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars.
#
# seaborn.barplot(, x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x7ff320f315e0>, ci=95, n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, dodge=True, ax=None, *kwargs)

# %%
sns.barplot(df['pclass'], df['survived'])
# Out:
# C:\Python3.10.4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='survived'>

# %% [markdown]
# From the above observation we can see that it is an comparision betweem pclass and survived columns.
#
# where we got to know that the people who have travelled in the first class survived the most and the people travelled using third class died the most.

# %%
sns.barplot(df['sex'], df['survived'])
# Out:
# C:\Python3.10.4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %% [markdown]
# From the above we can see the comparision of sex with respect to survived and we can observed that the female susrvived the most than compare to male.

# %%
sns.barplot(df['sibsp'], df['survived'])
# Out:
# C:\Python3.10.4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sibsp', ylabel='survived'>

# %% [markdown]
# From the observation we can see that sibsp i.e. a relation holder have saved there atlest one memeber from there family
#
# Eg: married man may save his child or wife or mother in this way the grap represent.

# %% [markdown]
# # Scatter plot
#
# scatterplot() function is used to plot the data and depict the relationship between the values using the scatter visualization.
#
# seaborn.scatterplot(*, x=None, y=None, hue=None, style=None, size=None, data=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, x_bins=None, y_bins=None, units=None, estimator=None, ci=95, n_boot=1000, alpha=None, x_jitter=None, y_jitter=None, legend='auto', ax=None, **kwargs)

# %%
sns.scatterplot(x = 'who', y ='fare',hue='alive', data=df,sizes=(20,200),size='who')
# Out:
# <AxesSubplot:xlabel='who', ylabel='fare'>

# %% [markdown]
# From the above observation we can see that its a comparision between who and fare based on the condition weather the passenger is alive and he is a man, woman or child.
#
# my observation says that woman survived the most of all then comes the child and the last man survived

# %%
sns.scatterplot(x = 'age', y ='fare',hue='who', data=df,style='who',alpha=1, legend='brief')
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %% [markdown]
# From this observation we can see that age group less than 15 years are child and from the age group between 20 to soon all other than child come.

# %% [markdown]
# ## cat plot
#
# catplot shows frequencies (or optionally fractions or percents) of the categories of one, two or three categorical variables.

# %% [markdown]
# seaborn.catplot(*, x=None, y=None, hue=None, data=None, row=None, col=None, col_wrap=None, estimator=<function mean at 0x7ff320f315e0>, ci=95, n_boot=1000, units=None, seed=None, order=None, hue_order=None, row_order=None, col_order=None, kind='strip', height=5, aspect=1, orient=None, color=None, palette=None, legend=True, legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, **kwargs)

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# dodge= When hue nesting is used, whether elements should be shifted along the categorical axis.
sns.catplot(x='day',y='total_bill',data=df,hue='sex',kind='box',dodge=True, estimator=np.mean)

# %% [markdown]
# From the above observation we can see that male people pay more bills as compare to women an all the week days. we are are also constructing the 5 number summary based on mean.

# %%
sns.catplot(x='day',y='total_bill',data=df,hue='sex',kind='box',dodge=False,estimator=np.median)

# %% [markdown]
# From the above observation we can see that male people pay more bills as compare to women an all the week days. we are are also constructing the 5 number summary based on median.
